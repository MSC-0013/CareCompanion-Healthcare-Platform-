# %%
# Install the Hugging Face Transformers, Datasets, and Accelerate libraries
# These are the core tools for fine-tuning modern AI models.
# !pip install transformers[torch] datasets accelerate --quiet

print("✅ Libraries installed successfully!")
# Out:
# ✅ Libraries installed successfully!
